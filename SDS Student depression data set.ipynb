# %%
#data set of student depression Dataset 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
adarsh=pd.read_csv(r"E:\student depression\student_depression_dataset.csv")
adarsh
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
adarsh.head (20)
# Out:
#      id  Gender   Age           City Profession  Academic Pressure  \
# 0     2    Male  33.0  Visakhapatnam    Student                5.0
# 1     8  Female  24.0      Bangalore    Student                2.0
# 2    26    Male  31.0       Srinagar    Student                3.0
# 3    30  Female  28.0       Varanasi    Student                3.0
# 4    32  Female  25.0         Jaipur    Student                4.0
# 5    33    Male  29.0           Pune    Student                2.0
# 6    52    Male  30.0          Thane    Student                3.0
# 7    56  Female  30.0        Chennai    Student                2.0
# 8    59    Male  28.0         Nagpur    Student                3.0
# 9    62    Male  31.0         Nashik    Student                2.0
# 10   83    Male  24.0         Nagpur    Student                3.0
# 11   91    Male  33.0       Vadodara    Student                3.0
# 12   94    Male  27.0         Kalyan    Student                5.0
# ...

# %%
adarsh.tail (20)
# Out:
#            id  Gender   Age         City Profession  Academic Pressure  \
# 27881  140564    Male  27.0        Surat    Student                4.0
# 27882  140568  Female  28.0  Vasai-Virar    Student                2.0
# 27883  140584  Female  22.0       Kanpur    Student                4.0
# 27884  140594    Male  18.0       Meerut    Student                5.0
# 27885  140597  Female  19.0       Mumbai    Student                2.0
# 27886  140601  Female  22.0       Jaipur    Student                5.0
# 27887  140624    Male  32.0       Rajkot    Student                4.0
# 27888  140630    Male  19.0      Kolkata    Student                4.0
# 27889  140631    Male  33.0    Ahmedabad    Student                1.0
# 27890  140635    Male  28.0     Ludhiana    Student                3.0
# 27891  140645  Female  28.0        Thane    Student                4.0
# 27892  140669  Female  20.0       Indore    Student                3.0
# ...

# %%
adarsh.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
adarsh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
adarsh.describe
# Out:
# <bound method NDFrame.describe of            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
# ...

# %%
# Univariate Analysis: Numerical
sns.histplot(adarsh['Age'], kde=True).set_title('Age Distribution')
plt.show()

# %%
# Univariate Analysis: Numerical
sns.histplot(adarsh['CGPA'], kde=True).set_title('CGPA Distribution')
plt.show()

# %%
# Univariate Analysis: Numerical
sns.histplot(adarsh['Work/Study Hours'], kde=True).set_title('Work/Study Hours Distribution')
plt.show()

# %%
# Univariate Analysis: Categorical
sns.countplot(x='Gender', data=adarsh).set_title('Gender Count')
plt.show()

# %%
# Univariate Pie Chart: Gender distribution
gender_counts = adarsh['Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution')
plt.show()

# %%
# Univariate Analysis: Categorical
sns.countplot(x='Depression', data=adarsh).set_title('Depression Count')
plt.show()

# %%
# Univariate Pie Chart: Depression distribution
depression_counts = adarsh['Depression'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(depression_counts, labels=['Not Depressed', 'Depressed'], autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
plt.title('Depression Distribution')
plt.show()

# %%
# Univariate Analysis: Categorical
sns.countplot(x='Dietary Habits', data=adarsh).set_title('Dietary Habits')
plt.show()

# %%
# Univariate Pie Chart: Dietary Habits
diet_counts = adarsh['Dietary Habits'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(diet_counts, labels=diet_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Dietary Habits Distribution')
plt.show()

# %%
#Age vs Academic Pressure Colored by Dietary Habits scaatter plot
sns.scatterplot(x='Age', y='Academic Pressure',hue='Dietary Habits',  data=adarsh, alpha=0.8)
plt.title('Age vs Academic Pressure Colored by Dietary Habits')
plt.xlabel('Age')
plt.ylabel('Academic Pressure')
plt.grid(True)
plt.show()

# %%
# Scatter plot colored by Gender
sns.scatterplot(x='CGPA', y='Work/Study Hours', hue='Gender', data=aa, alpha=0.7)
plt.title('CGPA vs Work/Study Hours Colored by Gender')
plt.xlabel('CGPA')
plt.ylabel('Work/Study Hours')
plt.grid(True)
plt.show()

# %%
#Work/Study Hours vs Age scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(adarsh['Work/Study Hours'], adarsh['Age'], color='teal', alpha=0.5)
plt.title('Work/Study Hours vs Age')
plt.xlabel('Work/Study Hours')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %%
# Scatter plot with hue based on Depression
sns.scatterplot(x='CGPA', y='Academic Pressure', hue='Depression', data=adarsh)
plt.title('CGPA vs Academic Pressure by Depression')
plt.xlabel('CGPA')
plt.ylabel('Academic Pressure')
plt.show()

# %%
# Scatter plot(CGPA vs Academic Pressure)
plt.figure(figsize=(8, 6))
plt.scatter(adarsh['CGPA'], adarsh['Academic Pressure'], alpha=0.6, c='purple')
plt.title('CGPA vs Academic Pressure')
plt.xlabel('CGPA')
plt.ylabel('Academic Pressure')
plt.grid(True)
plt.show()

# %%
#  Bivariate Analysis Depression vs Gender
sns.countplot(x='Gender', hue='Depression', data=adarsh)
plt.title('Depression by Gender')
plt.show()

# %%
#  Bivariate Analysis Depression vs CGPA
sns.boxplot(x='Depression', y='CGPA',hue='Depression', data=adarsh)
plt.title('CGPA by Depression')
plt.show()

# %%
# Bivariate Analysis Depression vs Academic Pressure
sns.boxplot(x='Depression', y='Academic Pressure',hue='Depression', data=adarsh)
plt.title('Academic Pressure by Depression')
plt.show()

# %%
# Scatter Plot (Bivariate): CGPA vs Academic Pressure, colored by Depression
sns.scatterplot(x='CGPA', y='Academic Pressure', hue='Depression', data=adarsh, alpha=0.7)
plt.title('CGPA vs Academic Pressure (Colored by Depression)')
plt.xlabel('CGPA')
plt.ylabel('Academic Pressure')
plt.grid(True)
plt.show()

# %%
# Filter for Male& female students
male_df = adarsh[adarsh['Gender'] == 'Male']
female_df = adarsh[adarsh['Gender'] == 'Female']

# Get Depression value counts
male_dep_counts = male_df['Depression'].value_counts()
female_dep_counts = female_df['Depression'].value_counts()

# Plot Mlae pie chart
plt.figure(figsize=(6, 6))
plt.pie(male_dep_counts, labels=['Not Depressed', 'Depressed'], autopct='%1.1f%%', colors=['skyblue', 'salmon'])
plt.title('Depression Distribution in Male Students')
plt.show()
# Plot Female Pie Chart
plt.figure(figsize=(6, 6))
plt.pie(female_dep_counts, labels=['Not Depressed', 'Depressed'], autopct='%1.1f%%', colors=['skyblue', 'salmon'])
plt.title('Depression Distribution in Female Students')
plt.show()

# %%
# Pairplot with Depression hue  Multivariate Analysis
selected_columns = ['Age', 'CGPA', 'Work/Study Hours', 'Academic Pressure', 'Depression']
sns.pairplot(adarsh[selected_columns], hue='Depression')
plt.suptitle("Pairplot of Selected Features", y=1.02)
plt.show()

# %%
# Multivariate Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x='CGPA',
    y='Academic Pressure',
    hue='Depression',
    size='Work/Study Hours',
    style='Gender',
    data=adarsh,
    palette='Set1',
    sizes=(50, 250),  # size range for points
    alpha=0.7
)

plt.title('Multivariate Scatter Plot: CGPA vs Academic Pressure')
plt.xlabel('CGPA')
plt.ylabel('Academic Pressure')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Correlation Heatmap
corr_matrix = adarsh.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
